# %%
import numpy as np
import matplotlib.pyplot as plt


def H(a,b,x):
    '''
    直线公式
    b是截距
    a是斜率
    '''
    return a*x+b

# %%
test_line = np.arange(100)
plt.plot(test_line,test_line)

# %%
testdata = np.cos(np.linspace(0,np.pi*2,20))
plt.plot(testdata),testdata
# Out:
# ([<matplotlib.lines.Line2D at 0x1185ecba8>],
#  array([ 1.        ,  0.94581724,  0.78914051,  0.54694816,  0.24548549,
#         -0.08257935, -0.40169542, -0.67728157, -0.87947375, -0.9863613 ,
#         -0.9863613 , -0.87947375, -0.67728157, -0.40169542, -0.08257935,
#          0.24548549,  0.54694816,  0.78914051,  0.94581724,  1.        ]))

# %%
N = 0.01
while N < 100:
    N += 1
    print(N)
# Out:
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# ...
