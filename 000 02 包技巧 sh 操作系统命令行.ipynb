# %%
from sh import find
from sh import pwd
from sh import Command
from sh import RunningCommand
import sh

# %%
find('/Users/zhangjing/Library/Mobile Documents/com~apple~CloudDocs/MyProject/InferenceSystem/src/I5_algorithm/NLP训练营笔记/南方网 2.csv')
# Out:
# ---------------------------------------------------------------------------
# ErrorReturnCode_1                         Traceback (most recent call last)
# <ipython-input-4-045a980ce2d0> in <module>
# ----> 1 find('/Users/zhangjing/Library/Mobile Documents/com~apple~CloudDocs/MyProject/InferenceSystem/src/I5_algorithm/NLP训练营笔记/南方网 2.csv')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sh.py in __call__(self, *args, **kwargs)
#    1514             stderr = open(str(stderr), "wb")
#    1515
# -> 1516         return RunningCommand(cmd, call_args, stdin, stdout, stderr)
#    1517
#    1518
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sh.py in __init__(self, cmd, call_args, stdin, stdout, stderr)
#     778
#     779             if should_wait:
# --> 780                 self.wait()
#     781
#     782     def wait(self, timeout=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sh.py in wait(self, timeout)
#     835
#     836             else:
# ...

# %%
pwd()
# Out:
# /Users/manmanzhang/Library/Mobile Documents/com~apple~CloudDocs/MyProject/InferenceSystem/src/I5_algorithm

# %%
Command("pwd")
# Out:
# <Command '/bin/pwd'>

# %%
sh.ls("-al")
# Out:
#  机器学习 TF-IDF 算法.ipynb
# -rw-r--r--    1 manmanzhang  staff    15638 Jul 29 14:37 006 机器学习 apriori关联算法.ipynb
# -rw-r--r--@   1 manmanzhang  staff   351458 Jun 13 15:34 006 机器学习 deeplearning （回归网络）莫烦动态神经网络学习.ipynb
# -rw-r--r--    1 manmanzhang  staff   121388 Jun 13 15:41 006 机器学习 numpy K-means误差平方和.ipynb
# -rw-r--r--    1 manmanzhang  staff    96597 Jun 13 15:42 006 机器学习 numpy手写距离.ipynb
# -rw-r--r--    1 manmanzhang  staff   148614 Jun 13 16:17 006 机器学习 numpy梯度下降调试代码.ipynb
# -rw-r--r--    1 manmanzhang  staff   124153 Jul  1 09:58 006 机器学习 sklearn 多项式回归示例demo.ipynb
# -rw-r--r--@   1 manmanzhang  staff     3985 Jun 13 15:33 006 机器学习 余弦相似度 调包实现 .ipynb
# -rw-r--r--@   1 manmanzhang  staff    24137 Jun 13 15:32 006 机器学习 决策树ID3.ipynb
# -rw-r--r--    1 manmanzhang  staff      599 Jul  1 20:45 006 机器学习 卷积.ipynb
# -rw-r--r--@   1 manmanzhang  staff    23831 Jul 12 22:10 006 机器学习 复旦中文模型.ipynb
# -rw-r--r--    1 manmanzhang  staff    63931 Jun 14 01:16 006 机器学习 多分类逻辑回归.ipynb
# ...

# %% [markdown]
# print (sh.df("-h"))                                #df -h 命令
#
# print (sh.echo("123456 abcde"))                    #echo 命令
#
# print (sh.free("-m"))                              #free -m 命令
#
# print (sh.fdisk("-l"))                             #fdisk -l 命令
#
# sh.mkdir("-p","python_sh_test")                    #mkdir 命令
#
# sh.touch("python_sh_test/py_test.txt")             #touch 命令
#
# print (sh.cat("python_sh_test/py_test.txt"))       #cat 命令
#
# print (sh.tail("-5","python_sh_test/py_test.txt")) #tail -n 命令
#
# #print (sh.ls("-l"))                               #ls -l 命令
#
# #print (sh.xargs(sh.ls("-l")))        #ls -l |xargs命令 (管道是有序的，默认由内而外)
#
# #print (sh.grep(sh.ls("-l"),"txt$"))  #ls -l |grep txt$命令(管道是有序的，默认由内而外)
