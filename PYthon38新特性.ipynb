# %%
import numpy as np

# %%
# %time
[a := np.dot(np.arange(i),np.arange(i)) for i in range(100000)]
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 4.05 µs
# [0,
#  0,
#  1,
#  5,
#  14,
#  30,
#  55,
#  91,
#  140,
#  204,
#  285,
#  385,
#  506,
#  650,
#  819,
#  1015,
#  1240,
#  1496,
#  1785,
#  2109,
#  2470,
#  2870,
#  3311,
#  3795,
#  4324,
#  4900,
#  5525,
#  6201,
#  6930,
#  7714,
#  8555,
#  9455,
#  10416,
#  11440,
#  12529,
#  13685,
#  14910,
#  16206,
#  17575,
#  19019,
#  20540,
#  22140,
#  23821,
#  25585,
#  27434,
#  29370,
#  31395,
#  33511,
#  35720,
#  38024,
#  40425,
#  42925,
#  45526,
#  48230,
#  51039,
#  53955,
#  56980,
#  60116,
#  63365,
#  66729,
#  70210,
#  73810,
#  77531,
#  81375,
#  85344,
#  89440,
#  93665,
#  98021,
#  102510,
#  107134,
#  111895,
#  116795,
#  121836,
#  127020,
#  132349,
#  137825,
#  143450,
#  149226,
#  155155,
#  161239,
#  167480,
#  173880,
#  180441,
#  187165,
#  194054,
#  201110,
#  208335,
#  215731,
#  223300,
#  231044,
#  238965,
#  247065,
#  255346,
#  263810,
#  272459,
#  281295,
#  290320,
#  299536,
#  308945,
#  318549,
#  328350,
#  338350,
#  348551,
#  358955,
#  369564,
#  380380,
#  391405,
#  402641,
#  414090,
#  425754,
#  437635,
#  449735,
#  462056,
#  474600,
#  487369,
#  500365,
#  513590,
#  527046,
#  540735,
#  554659,
#  568820,
#  583220,
#  597861,
#  612745,
#  627874,
#  643250,
#  658875,
#  674751,
#  690880,
#  707264,
#  723905,
#  740805,
#  757966,
#  775390,
#  793079,
#  811035,
#  829260,
#  847756,
#  866525,
#  885569,
#  904890,
#  924490,
#  944371,
#  964535,
#  984984,
#  1005720,
#  1026745,
#  1048061,
#  1069670,
#  1091574,
#  1113775,
#  1136275,
#  1159076,
#  1182180,
#  1205589,
#  1229305,
#  1253330,
#  1277666,
#  1302315,
#  1327279,
#  1352560,
#  1378160,
#  1404081,
#  1430325,
#  1456894,
#  1483790,
#  1511015,
#  1538571,
#  1566460,
#  1594684,
#  1623245,
#  1652145,
#  1681386,
#  1710970,
#  1740899,
#  1771175,
#  1801800,
#  1832776,
#  1864105,
#  1895789,
#  1927830,
#  1960230,
#  1992991,
#  2026115,
#  2059604,
#  2093460,
#  2127685,
#  2162281,
#  2197250,
#  2232594,
#  2268315,
#  2304415,
#  2340896,
#  2377760,
#  2415009,
#  2452645,
#  2490670,
#  2529086,
#  2567895,
#  2607099,
#  2646700,
#  2686700,
#  2727101,
#  2767905,
#  2809114,
#  2850730,
#  2892755,
#  2935191,
#  2978040,
#  3021304,
#  3064985,
#  3109085,
#  3153606,
#  3198550,
#  3243919,
#  3289715,
#  3335940,
#  3382596,
#  3429685,
#  3477209,
#  3525170,
#  3573570,
#  3622411,
#  3671695,
#  3721424,
#  3771600,
#  3822225,
#  3873301,
#  3924830,
#  3976814,
#  4029255,
#  4082155,
#  4135516,
#  4189340,
#  4243629,
#  4298385,
#  4353610,
#  4409306,
#  4465475,
#  4522119,
#  4579240,
#  4636840,
#  4694921,
#  4753485,
#  4812534,
#  4872070,
#  4932095,
#  4992611,
#  5053620,
#  5115124,
#  5177125,
#  5239625,
#  5302626,
#  5366130,
#  5430139,
#  5494655,
#  5559680,
#  5625216,
#  5691265,
#  5757829,
#  5824910,
#  5892510,
#  5960631,
#  6029275,
#  6098444,
#  6168140,
#  6238365,
#  6309121,
#  6380410,
#  6452234,
#  6524595,
#  6597495,
#  6670936,
#  6744920,
#  6819449,
#  6894525,
#  6970150,
#  7046326,
#  7123055,
#  7200339,
#  7278180,
#  7356580,
#  7435541,
#  7515065,
#  7595154,
#  7675810,
#  7757035,
#  7838831,
#  7921200,
#  8004144,
#  8087665,
#  8171765,
#  8256446,
#  8341710,
#  8427559,
#  8513995,
#  8601020,
#  8688636,
#  8776845,
#  8865649,
#  8955050,
#  9045050,
#  9135651,
#  9226855,
#  9318664,
#  9411080,
#  9504105,
#  9597741,
#  9691990,
#  9786854,
#  9882335,
#  9978435,
#  10075156,
#  10172500,
#  10270469,
#  10369065,
#  10468290,
#  10568146,
#  10668635,
#  10769759,
#  10871520,
#  10973920,
#  11076961,
#  11180645,
#  11284974,
#  11389950,
#  11495575,
#  11601851,
#  11708780,
#  11816364,
#  11924605,
#  12033505,
#  12143066,
#  12253290,
#  12364179,
#  12475735,
#  12587960,
#  12700856,
#  12814425,
#  12928669,
#  13043590,
#  13159190,
#  13275471,
#  13392435,
#  13510084,
#  13628420,
#  13747445,
#  13867161,
#  13987570,
#  14108674,
#  14230475,
#  14352975,
#  14476176,
#  14600080,
#  14724689,
#  14850005,
#  14976030,
#  15102766,
#  15230215,
#  15358379,
#  15487260,
#  15616860,
#  15747181,
#  15878225,
#  16009994,
#  16142490,
#  16275715,
#  16409671,
#  16544360,
#  16679784,
#  16815945,
#  16952845,
#  17090486,
#  17228870,
#  17367999,
#  17507875,
#  17648500,
#  17789876,
#  17932005,
#  18074889,
#  18218530,
#  18362930,
#  18508091,
#  18654015,
#  18800704,
#  18948160,
#  19096385,
#  19245381,
#  19395150,
#  19545694,
#  19697015,
#  19849115,
#  20001996,
#  20155660,
#  20310109,
#  20465345,
#  20621370,
#  20778186,
#  20935795,
#  21094199,
#  21253400,
#  21413400,
#  21574201,
#  21735805,
#  21898214,
#  22061430,
#  22225455,
#  22390291,
#  22555940,
#  22722404,
#  22889685,
#  23057785,
#  23226706,
#  23396450,
#  23567019,
#  23738415,
#  23910640,
#  24083696,
#  24257585,
#  24432309,
#  24607870,
#  24784270,
#  24961511,
#  25139595,
#  25318524,
#  25498300,
#  25678925,
#  25860401,
#  26042730,
#  26225914,
#  26409955,
#  26594855,
#  26780616,
#  26967240,
#  27154729,
#  27343085,
#  27532310,
#  27722406,
#  27913375,
#  28105219,
#  28297940,
#  28491540,
#  28686021,
#  28881385,
#  29077634,
#  29274770,
#  29472795,
#  29671711,
#  29871520,
#  30072224,
#  30273825,
#  30476325,
#  30679726,
#  30884030,
#  31089239,
#  31295355,
#  31502380,
#  31710316,
#  31919165,
#  32128929,
#  32339610,
#  32551210,
#  32763731,
#  32977175,
#  33191544,
#  33406840,
#  33623065,
#  33840221,
#  34058310,
#  34277334,
#  34497295,
#  34718195,
#  34940036,
#  35162820,
#  35386549,
#  35611225,
#  35836850,
#  36063426,
#  36290955,
#  36519439,
#  36748880,
#  36979280,
#  37210641,
#  37442965,
#  37676254,
#  37910510,
#  38145735,
#  38381931,
#  38619100,
#  38857244,
#  39096365,
#  39336465,
#  39577546,
#  39819610,
#  40062659,
#  40306695,
#  40551720,
#  40797736,
#  41044745,
#  41292749,
#  41541750,
#  41791750,
#  42042751,
#  42294755,
#  42547764,
#  42801780,
#  43056805,
#  43312841,
#  43569890,
#  43827954,
#  44087035,
#  44347135,
#  44608256,
#  44870400,
#  45133569,
#  45397765,
#  45662990,
#  45929246,
#  46196535,
#  46464859,
#  46734220,
#  47004620,
#  47276061,
#  47548545,
#  47822074,
#  48096650,
#  48372275,
#  48648951,
#  48926680,
#  49205464,
#  49485305,
#  49766205,
#  50048166,
#  50331190,
#  50615279,
#  50900435,
#  51186660,
#  51473956,
#  51762325,
#  52051769,
#  52342290,
#  52633890,
#  52926571,
#  53220335,
#  53515184,
#  53811120,
#  54108145,
#  54406261,
#  54705470,
#  55005774,
#  55307175,
#  55609675,
#  55913276,
#  56217980,
#  56523789,
#  56830705,
#  57138730,
#  57447866,
#  57758115,
#  58069479,
#  58381960,
#  58695560,
#  59010281,
#  59326125,
#  59643094,
#  59961190,
#  60280415,
#  60600771,
#  60922260,
#  61244884,
#  61568645,
#  61893545,
#  62219586,
#  62546770,
#  62875099,
#  63204575,
#  63535200,
#  63866976,
#  64199905,
#  64533989,
#  64869230,
#  65205630,
#  65543191,
#  65881915,
#  66221804,
#  66562860,
#  66905085,
#  67248481,
#  67593050,
#  67938794,
#  68285715,
#  68633815,
#  68983096,
#  69333560,
#  69685209,
#  70038045,
#  70392070,
#  70747286,
#  71103695,
#  71461299,
#  71820100,
#  72180100,
#  72541301,
#  72903705,
#  73267314,
#  73632130,
#  73998155,
#  74365391,
#  74733840,
#  75103504,
#  75474385,
#  75846485,
#  76219806,
#  76594350,
#  76970119,
#  77347115,
#  77725340,
#  78104796,
#  78485485,
#  78867409,
#  79250570,
#  79634970,
#  80020611,
#  80407495,
#  80795624,
#  81185000,
#  81575625,
#  81967501,
#  82360630,
#  82755014,
#  83150655,
#  83547555,
#  83945716,
#  84345140,
#  84745829,
#  85147785,
#  85551010,
#  85955506,
#  86361275,
#  86768319,
#  87176640,
#  87586240,
#  87997121,
#  88409285,
#  88822734,
#  89237470,
#  89653495,
#  90070811,
#  90489420,
#  90909324,
#  91330525,
#  91753025,
#  92176826,
#  92601930,
#  93028339,
#  93456055,
#  93885080,
#  94315416,
#  94747065,
#  95180029,
#  95614310,
#  96049910,
#  96486831,
#  96925075,
#  97364644,
#  97805540,
#  98247765,
#  98691321,
#  99136210,
#  99582434,
#  100029995,
#  100478895,
#  100929136,
#  101380720,
#  101833649,
#  102287925,
#  102743550,
#  103200526,
#  103658855,
#  104118539,
#  104579580,
#  105041980,
#  105505741,
#  105970865,
#  106437354,
#  106905210,
#  107374435,
#  107845031,
#  108317000,
#  108790344,
#  109265065,
#  109741165,
#  110218646,
#  110697510,
#  111177759,
#  111659395,
#  112142420,
#  112626836,
#  113112645,
#  113599849,
#  114088450,
#  114578450,
#  115069851,
#  115562655,
#  116056864,
#  116552480,
#  117049505,
#  117547941,
#  118047790,
#  118549054,
#  119051735,
#  119555835,
#  120061356,
#  120568300,
#  121076669,
#  121586465,
#  122097690,
#  122610346,
#  123124435,
#  123639959,
#  124156920,
#  124675320,
#  125195161,
#  125716445,
#  126239174,
#  126763350,
#  127288975,
#  127816051,
#  128344580,
#  128874564,
#  129406005,
#  129938905,
#  130473266,
#  131009090,
#  131546379,
#  132085135,
#  132625360,
#  133167056,
#  133710225,
#  134254869,
#  134800990,
#  135348590,
#  135897671,
#  136448235,
#  137000284,
#  137553820,
#  138108845,
#  138665361,
#  139223370,
#  139782874,
#  140343875,
#  140906375,
#  141470376,
#  142035880,
#  142602889,
#  143171405,
#  143741430,
#  144312966,
#  144886015,
#  145460579,
#  146036660,
#  146614260,
#  147193381,
#  147774025,
#  148356194,
#  148939890,
#  149525115,
#  150111871,
#  150700160,
#  151289984,
#  151881345,
#  152474245,
#  153068686,
#  153664670,
#  154262199,
#  154861275,
#  155461900,
#  156064076,
#  156667805,
#  157273089,
#  157879930,
#  158488330,
#  159098291,
#  159709815,
#  160322904,
#  160937560,
#  161553785,
#  162171581,
#  162790950,
#  163411894,
#  164034415,
#  164658515,
#  165284196,
#  165911460,
#  166540309,
#  167170745,
#  167802770,
#  168436386,
#  169071595,
#  169708399,
#  170346800,
#  170986800,
#  171628401,
#  172271605,
#  172916414,
#  173562830,
#  174210855,
#  174860491,
#  175511740,
#  176164604,
#  176819085,
#  177475185,
#  178132906,
#  178792250,
#  179453219,
#  180115815,
#  180780040,
#  181445896,
#  182113385,
#  182782509,
#  183453270,
#  184125670,
#  184799711,
#  185475395,
#  186152724,
#  186831700,
#  187512325,
#  188194601,
#  188878530,
#  189564114,
#  190251355,
#  190940255,
#  191630816,
#  192323040,
#  193016929,
#  193712485,
#  194409710,
#  195108606,
#  195809175,
#  196511419,
#  197215340,
#  197920940,
#  198628221,
#  199337185,
#  200047834,
#  200760170,
#  201474195,
#  202189911,
#  202907320,
#  203626424,
#  204347225,
#  205069725,
#  205793926,
#  206519830,
#  207247439,
#  207976755,
#  208707780,
#  209440516,
#  210174965,
#  210911129,
#  211649010,
#  212388610,
#  213129931,
#  213872975,
#  214617744,
#  215364240,
#  216112465,
#  216862421,
#  217614110,
#  218367534,
#  219122695,
#  219879595,
#  220638236,
#  221398620,
#  222160749,
#  222924625,
#  223690250,
#  224457626,
#  225226755,
#  225997639,
#  226770280,
#  227544680,
#  228320841,
#  229098765,
#  229878454,
#  230659910,
#  231443135,
#  232228131,
#  233014900,
#  233803444,
#  234593765,
#  235385865,
#  236179746,
#  236975410,
#  237772859,
#  238572095,
#  239373120,
#  240175936,
#  240980545,
#  241786949,
#  242595150,
#  243405150,
#  244216951,
#  245030555,
#  245845964,
#  246663180,
#  247482205,
#  248303041,
#  249125690,
#  249950154,
#  250776435,
#  251604535,
#  252434456,
#  253266200,
#  254099769,
#  254935165,
#  255772390,
#  256611446,
#  257452335,
#  258295059,
#  259139620,
#  259986020,
#  260834261,
#  261684345,
#  262536274,
#  263390050,
#  264245675,
#  265103151,
#  265962480,
#  266823664,
#  267686705,
#  268551605,
#  269418366,
#  270286990,
#  271157479,
#  272029835,
#  272904060,
#  273780156,
#  274658125,
#  275537969,
#  276419690,
#  277303290,
#  278188771,
#  279076135,
#  279965384,
#  280856520,
#  281749545,
#  282644461,
#  283541270,
#  284439974,
#  285340575,
#  286243075,
#  287147476,
#  288053780,
#  288961989,
#  289872105,
#  290784130,
#  291698066,
#  292613915,
#  293531679,
#  294451360,
#  295372960,
#  296296481,
#  297221925,
#  298149294,
#  299078590,
#  300009815,
#  300942971,
#  301878060,
#  302815084,
#  303754045,
#  304694945,
#  305637786,
#  306582570,
#  307529299,
#  308477975,
#  309428600,
#  310381176,
#  311335705,
#  312292189,
#  313250630,
#  314211030,
#  315173391,
#  316137715,
#  317104004,
#  318072260,
#  319042485,
#  320014681,
#  320988850,
#  321964994,
#  322943115,
#  323923215,
#  324905296,
#  325889360,
#  326875409,
#  327863445,
#  328853470,
#  329845486,
#  330839495,
#  331835499,
#  ...]

# %%
a
# Out:
# 333318333549999

# %%
# %time
[b := i**9 for i in range(100000) if i > 99990 and i != 99999]
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs
# [999190291538772266116027239322169901661479511,
#  999280230356997160547145219341040379360182272,
#  999370176371191025048241682219529708280546393,
#  999460129581857632862026319003224551644322304,
#  999550089989500787460626312471875351560546875,
#  999640057594624322547097944058101818982137856,
#  999730032397732102056938261235212685904880317,
#  999820014399328020159596805375953920230399488]

# %%
b
# Out:
# 999820014399328020159596805375953920230399488

# %%
# %time
(a := i**9 for i in range(100000) if i > 99990 and i != 99999)
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 7.15 µs
# <generator object <genexpr> at 0x1211bd970>

# %%
a
# Out:
# 333318333549999

# %%
# %time
[s:=f"cos(i) 如果 i 可以被2整除 = {np.cos(i):0.3f}" if i %2 ==0 else f"圆周率*i  如果i 不能被2整除= {np.pi:0.3f}"for i in range(100000)]
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 3.81 µs
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.760',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.907',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.004',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.911',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.754',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.284',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.990',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.540',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.540',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.990',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.284',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.754',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.911',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.004',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.907',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.760',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.275',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.989',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.548',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.533',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.991',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.292',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.748',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.915',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.013',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.904',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.765',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.267',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.987',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.555',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.525',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.992',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.301',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.742',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.918',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.022',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.900',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.771',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.258',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.986',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.562',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.518',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.993',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.309',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.736',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.922',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.031',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.896',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.777',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.250',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.984',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.570',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.510',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.994',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.317',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.730',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.925',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.040',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.892',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.782',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.241',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.983',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.577',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.503',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.995',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.326',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.724',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.928',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.049',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.888',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.788',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.232',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.981',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.584',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.495',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.996',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.334',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.718',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.932',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.058',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.884',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.793',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.224',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.979',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.591',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.487',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.997',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.343',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.712',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.935',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.066',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.880',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.799',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.215',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.978',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.599',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.479',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.997',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.351',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.706',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.938',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.075',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.875',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.804',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.206',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.976',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.606',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.472',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.998',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.359',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.699',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.941',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.084',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.871',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.809',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.198',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.974',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.613',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.464',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.999',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.367',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.693',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.944',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.093',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.867',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.814',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.189',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.972',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.620',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.456',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.999',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.376',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.686',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.947',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.102',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.862',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.819',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.180',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.969',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.626',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.448',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.999',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.384',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.680',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.950',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.110',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.858',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.824',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.172',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.967',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.633',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.440',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -1.000',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.392',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.673',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.952',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.119',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.853',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.829',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.163',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.965',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.640',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.432',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 1.000',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.400',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.667',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.955',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.128',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.849',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.834',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.154',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.963',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.647',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.424',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -1.000',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.408',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.660',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.958',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.137',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.844',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.839',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.145',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.960',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.654',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.416',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 1.000',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.416',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.654',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.960',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.146',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.839',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.844',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.137',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.958',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.660',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.408',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -1.000',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.424',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.647',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.963',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.154',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.834',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.849',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.128',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.955',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.667',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.400',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 1.000',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.432',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.640',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.965',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.163',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.829',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.853',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.119',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.952',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.674',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.392',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -1.000',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.440',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.633',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.967',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.172',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.824',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.858',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.110',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.950',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.680',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.384',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.999',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.448',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.626',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.969',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.180',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.819',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.862',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.102',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.947',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.687',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.375',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.999',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.456',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.619',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.972',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.189',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.814',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.867',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.093',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.944',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.693',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.367',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.999',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.464',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.613',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.974',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.198',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.809',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.871',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.084',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.941',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.699',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.359',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.998',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.472',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.605',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.976',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.207',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.804',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.875',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.075',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.938',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.706',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.351',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.997',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.479',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.598',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.978',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.215',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.798',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.880',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.066',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.935',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.712',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.342',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.997',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.487',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.591',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.979',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.224',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.793',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.884',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.057',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.932',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.718',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.334',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.996',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.495',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.584',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.981',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.232',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.788',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.888',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.049',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.928',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.724',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.326',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.995',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.503',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.577',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.983',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.241',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.782',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.892',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.040',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.925',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.730',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.317',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.994',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.510',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.570',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.984',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.250',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.777',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.896',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.031',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.922',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.736',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.309',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = -0.993',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  'cos(i) 如果 i 可以被2整除 = 0.518',
#  '圆周率*i  如果i 不能被2整除= 3.142',
#  ...]

# %%
s
# Out:
# '圆周率*i  如果i 不能被2整除= 3.142'
