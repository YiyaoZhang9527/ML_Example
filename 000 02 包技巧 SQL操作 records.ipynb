# %% [markdown]
# https://www.zhihu.com/question/24590883/answer/799802849

# %%
import records
# 获取数据库
db = records.Database('mysql+pymysql://root:19881121@localhost:3306/address_dataset_from_ip')
# 查询
rows = db.query('select * from iris;')

# %%
tuple(rows)
# Out:
# (<Record {"sepal_length": "5.1", "sepal_width": "3.5", "petal_length": "1.4", "petal_width": "0.2", "species": "setosa"}>,
#  <Record {"sepal_length": "4.9", "sepal_width": "3.0", "petal_length": "1.4", "petal_width": "0.2", "species": "setosa"}>,
#  <Record {"sepal_length": "4.7", "sepal_width": "3.2", "petal_length": "1.3", "petal_width": "0.2", "species": "setosa"}>,
#  <Record {"sepal_length": "4.6", "sepal_width": "3.1", "petal_length": "1.5", "petal_width": "0.2", "species": "setosa"}>,
#  <Record {"sepal_length": "5.0", "sepal_width": "3.6", "petal_length": "1.4", "petal_width": "0.2", "species": "setosa"}>,
#  <Record {"sepal_length": "5.4", "sepal_width": "3.9", "petal_length": "1.7", "petal_width": "0.4", "species": "setosa"}>,
#  <Record {"sepal_length": "4.6", "sepal_width": "3.4", "petal_length": "1.4", "petal_width": "0.3", "species": "setosa"}>,
#  <Record {"sepal_length": "5.0", "sepal_width": "3.4", "petal_length": "1.5", "petal_width": "0.2", "species": "setosa"}>,
# ...
