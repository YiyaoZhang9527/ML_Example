# %%
url = "https://www.cnblogs.com/sunbingqiang/p/9273362.html"
import requests
rsp = requests.get(url)
rsp
# Out:
# <Response [200]>

# %%
import pandas as pd
table = pd.read_html(rsp.text)[0]
table
# Out:
#               0         1           2             3           4
# 0     addressID  townName  ProvinceID  ProvinceName  RegionName
# 1        110000       北京市          11           北京市        华北地区
# 2        110100       市辖区          11           北京市        华北地区
# 3        110101       东城区          11           北京市        华北地区
# 4        110102       西城区          11           北京市        华北地区
# ...         ...       ...         ...           ...         ...
# 3506     659003     图木舒克市          65      新疆维吾尔自治区        西北地区
# 3507     659004      五家渠市          65      新疆维吾尔自治区        西北地区
# 3508     710000       台湾省          71     台湾地区(886)        特别地区
# 3509     810000   香港特别行政区          81  香港特别行政区（852)        特别地区
# 3510     820000   澳门特别行政区          82  澳门特别行政区（853)        特别地区
#
# [3511 rows x 5 columns]

# %%
table.to_csv("身份证号.csv")

# %%
from IPython.display import IFrame
url = "https://www.cnblogs.com/sunbingqiang/p/12725686.html"
IFrame(url,height=1080,width=1920)
# Out:
#         <iframe
#             width="1920"
#             height="1080"
#             src="https://www.cnblogs.com/sunbingqiang/p/12725686.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame("https://www.jianshu.com/p/55755fc649b1",height=1080,width=1920)
# Out:
#         <iframe
#             width="1920"
#             height="1080"
#             src="https://www.jianshu.com/p/55755fc649b1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
table
# Out:
#               0         1           2             3           4
# 0     addressID  townName  ProvinceID  ProvinceName  RegionName
# 1        110000       北京市          11           北京市        华北地区
# 2        110100       市辖区          11           北京市        华北地区
# 3        110101       东城区          11           北京市        华北地区
# 4        110102       西城区          11           北京市        华北地区
# ...         ...       ...         ...           ...         ...
# 3506     659003     图木舒克市          65      新疆维吾尔自治区        西北地区
# 3507     659004      五家渠市          65      新疆维吾尔自治区        西北地区
# 3508     710000       台湾省          71     台湾地区(886)        特别地区
# 3509     810000   香港特别行政区          81  香港特别行政区（852)        特别地区
# 3510     820000   澳门特别行政区          82  澳门特别行政区（853)        特别地区
#
# [3511 rows x 5 columns]

# %% [markdown]
# # 承志的算法课堂
# https://www.toutiao.com/c/user/token/MS4wLjABAAAAL6991lQbNOgAGUWmvWrmBntypTGE_FXXepZH3UAdYvY/
#
#
#
#
# 第6天 | 10天搞定Python网络爬虫，爬盗墓笔记，牛
# https://www.toutiao.com/a6889239902941250056/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604440182&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202011040549420102040280242E1035F4&group_id=6889239902941250056s
#
# 如何使用Photon高效率提取网站数据
# https://cloud.tencent.com/developer/news/301046
#
#
#
#
#
# 欧拉数e的python-matplotlib可视化
# https://www.toutiao.com/a6880839468266291723/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1602095024&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202010080223440101941000504A3D35D4&group_id=6880839468266291723
#
# matplotlib设置颜色、标记、线条，让你的图像更加丰富
# https://www.toutiao.com/i6875871112136229389/
#
# matplotlib绘图教程，设置标签与图例
# https://www.toutiao.com/i6880322104860869133/
#
# matplotlib，使用Python轻松做出各类图表
# https://www.toutiao.com/i6871047178844897799/
#
# 14个Seaborn数据可视化图
# https://www.toutiao.com/i6879923438241186317/
#
#
#
# 动态规划经典教学题 编辑距离
# https://www.toutiao.com/i6831719956095173127/
#
# 算法数据结构 | 图论基础算法——拓扑排序
# https://www.toutiao.com/i6865509864550957571/
#
# 详解匈牙利算法与二分图匹配
# https://www.toutiao.com/i6862165977010962957/
#
# 还在为并查集算法发愁？只需要四十行代码就够了
# https://www.toutiao.com/i6821479403113939463/
#
# 学算法还能指导找对象？是的，这就是大名鼎鼎的稳定婚姻算法
# https://www.toutiao.com/i6858070696577204750/
#
# LeetCode 89，因为题目晦涩而被点了1500+反对的搜索问题
# https://www.toutiao.com/i6856973565598630411/
#
# 算法数据结构 | 只要30行代码，实现快速匹配字符串的KMP算法
# https://www.toutiao.com/i6854730621588242951/
#
# 博弈论 | 详解搞定组合博弈问题的SG函数
# https://www.toutiao.com/i6846943149185565188/
#
# 博弈论Nim取子问题，困扰千年的问题一行代码解决
# https://www.toutiao.com/i6843996776731509261/
#
# 每个人都能读懂的最小生成树算法（Kruskal）
# https://www.toutiao.com/i6824074861153878539/
#
# 最小生成树的本质是什么？Prim算法道破天机
# https://www.toutiao.com/i6826878359918608908/
#
# 数据结构 | 30行代码，手把手带你实现Trie树
# https://www.toutiao.com/i6851151556264329736/
#
# 博弈论——两人取子游戏与威佐夫博弈，隐藏在背后的黄金分割
# https://www.toutiao.com/i6840281316097786372/
#
# 只用一行代码就能搞定，博弈论究竟是什么神仙算法？
# https://www.toutiao.com/i6837681014911795715/
#
#
#
#
# python git 基础操作
# https://www.cnblogs.com/binw/p/12028423.html
#
#
#
# 一文四种方法学会文本预处理干货
# https://www.toutiao.com/a6890873327120810504/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604439912&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=2020110405451101020208608654100400&group_id=6890873327120810504
#
# 机器学习基础——详解自然语言处理之tf-idf
# https://www.toutiao.com/i6800138285566919175/
#
# 在PyTorch中使用Seq2Seq构建的神经机器翻译模型
# https://www.toutiao.com/i6873617938365022732/
#
#
#
#
#
# 机器学习基础——简单易懂的K邻近算法，根据邻居“找自己”
# https://www.toutiao.com/i6802743251511017997/
#
# 机器学习基础——笔试面试常考的Kmeans聚类算法
# https://www.toutiao.com/i6805339775944360462/
# 详解Kmeans算法的经典优化——mini-batch和Kmeans++
# https://www.toutiao.com/i6807937402024231427/
#
# 讲透机器学习中的梯度下降
# https://www.toutiao.com/i6792355052896911884/
# 机器学习基础——线性回归公式推导（附代码和演示图）
# https://www.toutiao.com/i6789758440169275908/
# 详解机器学习损失函数之交叉熵
# https://www.toutiao.com/i6797555451723514382/
# 机器学习——一文详解逻辑回归「附详细推导和代码
# https://www.toutiao.com/i6794951283099828749/
#
# PCA算法 | 数据集特征数量太多怎么办？用这个算法对它降维打击
# https://www.toutiao.com/i6846591085473432076/
#
# 机器学习十大经典算法之EM算法
# https://www.toutiao.com/a6810550883361751560/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1602242019&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=2020100919133801001006217211118E56&group_id=6810550883361751560
#
# 机器学习基础——一篇文章让你学会朴素贝叶斯模型
# https://www.toutiao.com/i6781949890726461965/
# 机器学习基础——带你实战朴素贝叶斯模型文本分类
# https://www.toutiao.com/i6784550895540503052/
#
# 手把手教你用ID3算法实现决策树模型
# https://www.toutiao.com/i6829465601908408846/
# 深入了解机器学习决策树模型——C4.5算法
# https://www.toutiao.com/i6832081123942597123/
# 机器学习十大经典算法之一——决策树CART算法
# https://www.toutiao.com/i6835072343438524941/
# 机器学习——手把手教你用Python实现回归树模型
# https://www.toutiao.com/i6837283834531152395/
# 机器学习——动手从决策树实现随机森林
# https://www.toutiao.com/i6843600501280342532/
# 机器学习——打开集成方法的大门，手把手带你实现AdaBoost模型
# https://www.toutiao.com/i6839881862265963015/
#
#
# 机器学习 | 简介推荐场景中的协同过滤算法，以及SVD的使用
# https://www.toutiao.com/i6854363998389797389/
# 机器学习 | SVD矩阵分解算法，对矩阵做拆分，然后呢？
# https://www.toutiao.com/i6850285956772151816/
# 推荐系统基础：使用PyTorch进行矩阵分解
# https://www.toutiao.com/a6868423019627446791/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1601735655&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202010032234140100140460231A7941BB&group_id=6868423019627446791
#
# 强化学习的最基本概念马尔可夫决策过程简介
# https://www.toutiao.com/i6890706150027690508/
#
# 理解强化学习
# https://www.toutiao.com/i6884388360975024643/
#
# 使用卡尔曼滤波平滑时间序列，提高时序预测的准确率
# https://www.toutiao.com/i6873249961551593996/
#
# 逐步实现卡尔曼滤波器
# https://www.toutiao.com/a6666758827133633036/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604442666&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202011040631050102040551590710CE76&group_id=6666758827133633036
#
# 利用Python纯手工实现蒙特卡洛集成
# https://www.toutiao.com/a6858439350196109832/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604441604&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202011040613240100110601051210989A&group_id=6858439350196109832
#
# MCMC、蒙特卡洛近似和Metropolis算法简介
# https://www.toutiao.com/i6888096894002659848/
#
# 混淆矩阵、AUC、ROC，傻傻分不清楚？来看这篇就对了
# https://www.toutiao.com/i6821113508365599243/
#
# 随机游走deepinwalk
# https://toutiao.com/group/6766104546411282947/?app=news_article_social&timestamp=1604504071&use_new_style=1&req_id=20201104233430010202086095500C9B80&group_id=6766104546411282947&tt_from=mobile_qq&utm_source=mobile_qq&utm_medium=toutiao_ios&utm_campaign=client_share
#
# 把贝叶斯、奥卡姆和香农约一块儿，探讨下机器学习的定义
# https://www.toutiao.com/a6599483650624979469/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604466377&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202011041306160101941000984F0487DD&group_id=6599483650624979469
#
# 分布式初探——判断因果关系的向量时钟算法
# https://www.toutiao.com/i6790914312366981645/
#
# 算法浅谈——怎么样才最有可能选中真命天子呢？
# https://www.toutiao.com/i6782317040599302667/
#
#
#
#
#
# 大数据算法——布隆过滤器
# https://www.toutiao.com/i6793479259584201229/
# 详解十大数据挖掘算法之Apriori
# https://www.toutiao.com/i6823687838966481421/
# 嫌弃Apriori算法太慢？使用FP-growth算法让你的数据挖掘快到飞起
# https://www.toutiao.com/i6826532031598428679/
#
# 机器学习基础——搜索引擎的原理和架构
# https://www.toutiao.com/i6774186269447553540/
# 机器学习基础——倒排索引与搜索引擎
# https://www.toutiao.com/i6779357267008422411/
#
#
#
# 线性代数精华1——从行列式开始
# https://www.toutiao.com/i6773880253216457219/
# 线性代数精华2——逆矩阵的推导过程
# https://www.toutiao.com/i6776386518664610316/
# 线性代数精华——矩阵的特征值与特征向量
# https://www.toutiao.com/i6789385468623454731/
# 线性代数精华——从正交向量到正交矩阵
# https://www.toutiao.com/i6784184747057742349/
# 线性代数精华——向量的线性相关与空间的基
# https://www.toutiao.com/i6781600877087031811/
# 线性代数精华——讲透矩阵的初等变换与矩阵的秩
# https://www.toutiao.com/i6778986164608041486/
#
#
#
#
#
# 概率统计——三扇门游戏与贝叶斯定理
# https://www.toutiao.com/i6777502420638368269/
#
# 概率统计——期望、方差与最小二乘法
# https://www.toutiao.com/i6785427364705731076/
#
# 举一个“栗子”讲清楚泊松分布
# https://www.toutiao.com/i6824482764264309256/
#
# 方差、协方差与皮尔逊值
# https://www.toutiao.com/i6827244269888078339/
#
# 概率统计——讲透最经典的三种概率分布
# https://www.toutiao.com/i6782691198655005187/
#
# 概率统计——为什么条件概率的结果总和直觉不同？
# https://www.toutiao.com/i6780096068609638916/
#
#
#
#
#
#
#
#
#
# 高等数学——讲透求极限两大方法，夹逼法与换元法
# https://www.toutiao.com/i6787896676695671308/
#
# 高等数学——导数的定义和常见导数
# https://www.toutiao.com/i6790548985800032775/
#
# 高等数学——复杂函数的求导方法
# https://www.toutiao.com/i6793099291201110535/
#
# 高等数学——详解洛必达法则
# https://www.toutiao.com/i6798297347559260686/
#
# 看完这篇让你高数不挂科之——泰勒公式
# https://www.toutiao.com/i6800919131072758286/
#
# 一文讲透高数中的微分中值定理
# https://www.toutiao.com/i6795689897442148868/
#
# 从辗转相除法到求逆元，数论算法初体验
# https://www.toutiao.com/i6832812368334946824/
#
# 快速求解方程的根——二分法与牛顿迭代法
# https://www.toutiao.com/i6803484894719640078/
#
# 高等数学——推导牛顿莱布尼茨定积分公式
# https://www.toutiao.com/i6819268202388783627/
#
# 高等数学——微积分中的不定积分
# https://www.toutiao.com/i6806082876128363019/
#
# 高等数学——求解不定积分的经典换元法
# https://www.toutiao.com/i6808689403251130888/
#
#
#
#
#
#
# 10行实现最短路算法——Dijkstra
# https://www.toutiao.com/i6870678228881637902/
#
# 10行代码实现的最短路算法—Bellmanford与SPFA
# https://www.toutiao.com/i6868462514028413447/
#
# LeetCode专题——详解搜索算法中的搜索策略和剪枝
# https://www.toutiao.com/i6804264995354837511/
#
# 算法浅谈——走迷宫问题与广度优先搜索
# https://www.toutiao.com/i6803120927987991048/
#
# 算法例题——从搜索算法推导到贪心
# https://www.toutiao.com/i6809805552554623491/
#
#
#
#
#
# 学习Numpy，看这篇文章就够啦
# https://www.toutiao.com/a6867453951122342412/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604440488&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202011040554470100140472091D105313&group_id=6867453951122342412
#
# 每个数据科学家都应该知道的20个NumPy操作
# https://www.toutiao.com/i6867315542043623949/
#
# Numpy中这些基础的api你都会用吗？
# https://www.toutiao.com/i6838032780203393539/
#
# python pandas速查手册
# https://www.toutiao.com/a6795410391703749123/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604441723&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202011040615230102040570914A107496&group_id=6795410391703749123
#
# Python专题——详解enumerate与zip用法
# https://www.toutiao.com/i6807566646958359044/
#
# Python——五分钟带你弄懂迭代器与生成器，夯实代码能力
# https://www.toutiao.com/i6802378943606292996/
#
# Python 项目代码写完了，然后怎么打包和发布？
# https://www.toutiao.com/a6858439350196109832/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604441604&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202011040613240100110601051210989A&group_id=6858439350196109832
#
# 数学证明深度学习激活函数从Softmax到Sparsemax
# https://www.toutiao.com/a6872268013207290376/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604440735&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202011040558550102020880313C103AF4&group_id=6872268013207290376
#
#
# shell中最强大，实用的命令awk，梳理清楚就是这么简单
# https://www.toutiao.com/a6710130734595572231/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1602242156&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202010091915560100120210161B123A47&group_id=6710130734595572231
#
# 60题PyTorch简易入门指南，做技术的弄潮儿
# https://zhuanlan.zhihu.com/p/250649565?utm_source=ZHShareTargetIDMore&utm_medium=social&utm_oi=737646268834152448
#
# 图神经网络之神器——PyTorch Geometric 上手 & 实战
# https://zhuanlan.zhihu.com/p/94491664?utm_source=ZHShareTargetIDMore&utm_medium=social&utm_oi=737646268834152448
#
# 让机器学习自动帮我们建模，这4个Python库能让你大开眼界
# https://www.toutiao.com/a6873417340151824904/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1602342618&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=20201010231017010014041155071AD2E5&group_id=6873417340151824904
#
# 到底什么是A/B测试？腾讯数据分析师手把手教你设计A/B测试
# https://www.toutiao.com/a6885912853551940099/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1603639215&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=202010252320140100140632281C19A0E4&group_id=6885912853551940099
#
# 知识蒸馏：如何用一个神经网络训练另一个神经网络
# https://www.toutiao.com/a6888480635548074507/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1603906022&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=2020102901270101020208805249138441&group_id=6888480635548074507
#
# 如何检查服务器是否被入侵？
# https://www.wukong.com/answer/6756151970723004679/
#
#
#
# LightGBM的参数详解以及如何调优
# https://www.toutiao.com/i6870295900175106563/
#
#
# 详解command设计模式，解耦操作和回滚
# https://www.toutiao.com/i6884035774665196039/
#
# 设计模式 | Catalog设计模式，抵御业务方需求变动
# https://www.toutiao.com/i6873641658370490891/
#
# 详解工程师不可不会的LRU缓存淘汰算法
# https://www.toutiao.com/i6883291035523351047/
#
# Python进阶——详解元类，metaclass的原理和用法
# https://www.toutiao.com/i6839511956634731020/
#
# 怎么在Python装饰器中自定义功能呢？用这种方法让你“为所欲为”
# https://www.toutiao.com/i6826336579242426887/
#
# Python装饰器不会传参？别着急，这篇文章为你解惑
# https://www.toutiao.com/i6823371614067884556/
#
# Python——详解collections工具库
# https://www.toutiao.com/i6799776825686884871/
#
# 一文搞定Python装饰器，看完面试不再慌
# https://www.toutiao.com/i6820922415606923784/
#
# 30段极简Python代码：这些小技巧你都Get了么
# https://www.toutiao.com/a6740081099646435847/?tt_from=mobile_qq&utm_campaign=client_share&timestamp=1604441774&app=news_article_social&utm_source=mobile_qq&utm_medium=toutiao_ios&use_new_style=1&req_id=20201104061613010202089131301091A2&group_id=6740081099646435847
#
# 随机数大家都会用，但是你知道生成随机数的算法吗？
# https://www.toutiao.com/i6891078346327720460/
#
# 一次找出范围内的所有素数，埃式筛法是什么神仙算法？
# https://www.toutiao.com/i6835413133494845956/
